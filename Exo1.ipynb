# %%
from random import randint
import sympy as sp
from IPython.display import display,Latex
sp.init_printing()
def coeff(m):
    a=randint(-m,m)
    if a==0:
        a==1
    return a
a=coeff(3)
listeAR=[sp.pi/6,sp.pi/4,sp.pi/3,sp.pi/2]
for k in range(4):
    listeAR.append(sp.pi-listeAR[k])
listeAR.append(0)
listeAR.append(sp.pi)
b=coeff(3)
z = sp.symbols('z')
arg=listeAR[randint(0,9)]
z3=a*(sp.E**(sp.I*arg))
z3=sp.re(z3)+sp.I*sp.im(z3)
z2=sp.conjugate(z3)
z1=-z3
P=sp.expand(a*(z-z1)*(z-z2)*(z-z3))
s='On munit le plan complexe du repère orthonormal $(O, \overrightarrow{u}, \overrightarrow{v} )$'
display(Latex(s))
s='$P(z)='
s='On considère le polynôme $P$, défini algébriquement par:'
display(Latex(s))
s='$P(z)='
s=s+sp.latex(P)+'$'
display(Latex(s))
s='Soit $z_{A}$ , défini par: $z_{A}='+sp.latex(z1)+'$'
display(Latex(s))
s='$\\textbf{1}$- Vérifier que $P$ admet $z_{A}$ comme racine et factoriser $P$.'
display(Latex(s))
s='On appelera $z_{B}$ et $z_{C}$ les autres racines éventuelles, avec $z_{B}$ de partie imaginaire positive.'
display(Latex(s))
s='$\\textbf{2}$-  Donner de $z_{B}$ et de $z_{C}$ la forme exponentielle.'
display(Latex(s))
s='$\\textbf{3}$-  Calculer la forme algébrique de $\\frac{z_{C}}{z_{A}}$, puis son module et argument.'
display(Latex(s)) 
s='Donner du résultat précédent une interprétation géométrique.'
display(Latex(s)) 
q=(z1-z2)/(z3-z2)
s='$\\textbf{4}$-  Calculer la forme algébrique, puis un argument  de $\\frac{z_{A}-z_{B}}{z_{C}-z_{B}}$.'
display(Latex(s)) 
s='$\\textbf{5}$-  Justifier la nature du triangle $ABC$ de plusieurs manières différentes:'
display(Latex(s)) 
s='$\\bigstar $ 5a- Justifier la nature du triangle $ABC$ avec la question 3.'
display(Latex(s)) 
s='$\\bigstar $ 5b- Justifier la nature du triangle $ABC$ avec la question 4.'
display(Latex(s)) 
s='$\\bigstar $  5c- Justifier la nature du triangle $ABC$ avec le produit scalaire de vecteurs à choisir.'
display(Latex(s)) 
s='$\\bigstar $ 5d- Justifier la nature du triangle $ABC$ avec le théorème de Pythagore.'
display(Latex(s))
# Out:
# On munit le plan complexe du repère orthonormal $(O, \overrightarrow{u}, \overrightarrow{v} )$
# On considère le polynôme $P$, défini algébriquement par:
# $P(z)=- 2 z^{3} + 4 i z^{2} - 8 z + 16 i$
# Soit $z_{A}$ , défini par: $z_{A}=2 i$
# $\textbf{1}$- Vérifier que $P$ admet $z_{A}$ comme racine et factoriser $P$.
# On appelera $z_{B}$ et $z_{C}$ les autres racines éventuelles, avec $z_{B}$ de partie imaginaire positive.
# $\textbf{2}$-  Donner de $z_{B}$ et de $z_{C}$ la forme exponentielle.
# $\textbf{3}$-  Calculer la forme algébrique de $\frac{z_{C}}{z_{A}}$, puis son module et argument.
# Donner du résultat précédent une interprétation géométrique.
# $\textbf{4}$-  Calculer la forme algébrique, puis un argument  de $\frac{z_{A}-z_{B}}{z_{C}-z_{B}}$.
# $\textbf{5}$-  Justifier la nature du triangle $ABC$ de plusieurs manières différentes:
# $\bigstar $ 5a- Justifier la nature du triangle $ABC$ avec la question 3.
# ...
